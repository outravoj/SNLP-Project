# %%
import sys
import json
from google.colab import drive
import pandas as pd
drive.mount("/content/gdrive")
df= pd.read_csv("/content/gdrive/MyDrive/Colab Notebooks/SNLP projekt/data/train.csv").head(250_000).dropna()
# Out:
# Mounted at /content/gdrive

# %%
qid1, qid2, question1, question2 = df["qid1"].to_list(), df["qid2"].to_list(), df["question1"].to_list(), df["question2"].to_list()

# %%
track = dict()
print(qid2[0])
for i in range(len(qid1)):
  track[qid1[i]] = question1[i]
  track[qid2[i]] = question2[i]
# Out:
# 2

# %%
with open('/content/gdrive/MyDrive/Colab Notebooks/SNLP projekt/LSH/sentences_dict.json', 'w') as fp:
    json.dump(track, fp)
